# %% [markdown]
# <a href="https://colab.research.google.com/github/ameena0726-ops/House-Price-Prediction/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK NO : 3**
